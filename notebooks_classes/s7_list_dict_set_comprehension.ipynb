# %% [markdown]
# # Session 7: List, set, dict comprehension
#
# In the past we've learn that, in order to create a new iterator using the information contained in an existing one, we can loop through each element, perfom some operation on them, and store the new items in our new iterable.
#
# There's a more Pythonic and efficient way to do that in Python, and it's the bread and butter of working with Python.

# %% [markdown]
# ## List comprehensions:
#
# General structure:
# ```Python
# new_list = [do_something_with_item for item in old_list]
# ```
#
# Let's compare the structure of that, with our well-known `for` loops:
# ```Python
# new_list = []
# for item in old_list:
#     new_item = do_something_with_item
#     new_list.append(new_item)
# ```
#
# The advantage seems clear right? Well, not only they're more compact, but also the performance is *usually* better.
#
# Let's check this with an example: given a list of numbers, return another list of the squares of the original list.

# %%
# %%timeit

# using for loop
old_list = [1, 2, 3, 4, 5]
new_list = []

for item in old_list:
    square = item ** 2
    new_list.append(square)
    
new_list
# Out:
# 1.31 µs ± 18.7 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit

# using list comprehensions
old_list = [1, 3, 5, 7]

new_list = [item**2 for item in old_list]

new_list
# Out:
# 976 ns ± 1.8 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ### Conditionals in lists comprehensions
#
# Just like we did with for loops, we can check for conditions within our list comprehensions:
#
# ```Python
# new_list = [do_something_if if condition else do_something_else for item in old_list]
# ```
#
# Let's use it in an example: given a list of numbers, return a new list containing "odd" or "even" accordingly:

# %%
# for loop and if-else structure:

old_list = [1, 3, 6, 10]
new_list = []

for item in old_list:
    if item % 2 == 0:
        new_list.append("even")
    else:
        new_list.append("odd")
        
new_list
# Out:
# ['odd', 'odd', 'even', 'even']

# %%
# using list comprehension and conditionals

old_list = [1, 3, 6, 10]

new_list = ["even" if item%2==0 else "odd" for item in old_list]

new_list
# Out:
# ['odd', 'odd', 'even', 'even']

# %% [markdown]
# We can also filter our lists based on a certain condition: given a list of letters, return a list only with vowels:

# %%
old_list = list("abhyjiuodejklougihe")
vowels = "aeiou"

new_list = [item for item in old_list if item in vowels]

new_list
# Out:
# ['a', 'i', 'u', 'o', 'e', 'o', 'u', 'i', 'e']

# %% [markdown]
# #### **Summary**
#
# **Basic list comprehension:**
# ```Python
# new_list = [
#     do_something_to_item for item in old_list
# ]
# ```
#
# **Using conditionals to operate each item with list comprehension:**
# ```Python
# new_list = [
#     do_something_to_item if condition else do_something_else_to_item
#     for item in old_list
# ]
# ```
#
# **Using conditionals to filter a list with list comprehension:**
# ```Python
# new_list = [item for item in old_list if condition]
# ```
#
# **Using conditionals to operate only items that meet a condition with list comprehension:**
# ```Python
# new_list = [
#     do_something_to_item if condition1 else do_something_else_to_item
#     for item in old_list if condition2
# ]
# ```

# %% [markdown]
# ### Exercise: filter list and change the results unfiltered.
#
# Given a list of names
# ```Python
# names = ["angelica", "eliza", "peggy", "alexander", "aaron", "james"]
# ```
# Return a new list:
# * Containing all the names that start with a vowel
#     * If second letter is vowel save it lower
#     * If second letter is consonant save it upper
#
# Result:
# ```Python
# >> ['ANGELICA', 'ELIZA', 'ALEXANDER', 'aaron']
# ```

# %%
names = ["angelica", "eliza", "peggy", "alexander", "aaron", "james"]

# %%
# using for loops
new_names = []

for name in names:
    if name[0] in "aeiou": # if the first letter is a vowel
        if name[1] in "aeiou": # if the second letter is a vowel
            new_names.append(name.lower()) # append the name in lowercase to the new list
        else:
            new_names.append(name.upper()) # append the name in uppercase to the new list
            
new_names
# Out:
# ['ANGELICA', 'ELIZA', 'ALEXANDER', 'aaron']

# %%
# list comprehensions
new_names = [
    name.lower() 
    if name[1] in "aeiou"
    else name.upper() 
    for name in names
    if name[0] in "aeiou"
]

new_names
# Out:
# ['ANGELICA', 'ELIZA', 'ALEXANDER', 'aaron']

# %% [markdown]
# ## Set comprehensions
#
# Just like ourlist comprehensions, but enclosing our code with curly brackets `{}`.
#
# Example:
# * Given a list of dates, return the unique dates from 2021
# ```Python
# list_dates = [
#     "2021-10-15", "2020-01-15", "2021-10-15",
#     "2020-10-15", "2021-01-15", "2021-06-15",
# ]
# ```
#
# Result:
# ```Python
# >> {"2021-10-15", "2021-01-15", "2021-06-15"}
# ```

# %%
# using for loops:
list_dates = [
  "2021-10-15", "2020-01-15", "2021-10-15",
  "2020-10-15", "2021-01-15", "2021-06-15",
]

# empty list to store the results
dates_2021 = []

# for loop
for dt in list_dates:
    if dt[:4] == "2021":
        dates_2021.append(dt)
        
unique_dates_2021 = set(dates_2021)
        
print(unique_dates_2021)
# Out:
# {'2021-06-15', '2021-10-15', '2021-01-15'}

# %%
# using list comprehensions

list_dates = [
  "2021-10-15", "2020-01-15", "2021-10-15",
  "2020-10-15", "2021-01-15", "2021-06-15",
]

unique_dates_2021 = {
    dt for dt in list_dates if dt[:4]=="2021" 
}

print(unique_dates_2021)
# Out:
# {'2021-06-15', '2021-10-15', '2021-01-15'}

# %% [markdown]
# ## Dictionary comprehensions
#
# We've learned how to work with list and set comprehensions. In those cases, being sequential, the structure is clear: `[do_something_to_item for item in sequence]`.
#
# But what if we want to work with dictionaries? Well, Python to the rescue.
#
# * We can create a dictionary out of a list using ListComp
# * We can create a dictionary out of another dictionary using ListComp
# * We can create a list out of a dictionary using ListComp

# %% [markdown]
# ### Dict from list
#
# Given a list of words, create a dictionary with the following format:
#
# ```Python
# {word: number_of_characters}
# ```

# %%
word_list = ["hello", "my", "name", "is", "daniel"]

dict_words = {word:len(word) for word in word_list}

# %% [markdown]
# ### Dict from dict
# Given a dictionary that contains words and their length, return another dictionary that contains for each word, the upper, lower, and capitalized version within a tuple.

# %%
dict_words = {'hello': 5, 'my': 2, 'name': 4, 'is': 2, 'daniel': 6}

new_dict = {
    word: (word.upper(), word.lower(), word.capitalize())
    for word, length in dict_words.items()
}

# %% [markdown]
# ### List from dict
#
# Given a dictionary of words and their lower, upper, and capitalized versions, return a list that only includes the lower versions.

# %%
word_version_dict = {
    'hello': ('HELLO', 'hello', 'Hello'), 
    'my': ('MY', 'my', 'My'), 
    'name': ('NAME', 'name', 'Name'), 
    'is': ('IS', 'is', 'Is'), 
    'daniel': ('DANIEL', 'daniel', 'Daniel')
}

lower_words_list = [
    versions[1]
    for word, versions in word_version_dict.items()
]

# %% [markdown]
# ## Multiple iteration
#
# Sometimes we want to build a list not just from one value, but from two. To do this, simply add another for expression in the comprehension:
#
# ```Python
# [(i, j) for i in iterable1 for j in iterable2]
# ```
#
# Which is the equivalent of the following structure using `for` loops:
# ```Python
# new_list = []
# for i in iterable1:
#     for j in iterable2:
#         new_list.append((i, j))
# ```
#
#
# Example:
# * Given a list of horizontal and vertical positions, create a grid in the following form
#
# ```Python
# [(x_1, y_1), (x_1, y_2), ..., (x_J, y_K)]
# ```

# %%
x_pos = [0, 1, 2, 3, 4, 5]
y_pos = [0, 1, 2, 3, 4, 5]

new_list = [
    (x, y) for x in x_pos for y in y_pos
]

# %% [markdown]
# ## Exercises:
#
# Using the `spotify` data, work on the following exercises
#
# But first, remember this is how you load the spotify data:
#
# ```Python
# import json
# with open("spotify.json") as json_file:
#     json_data = json.load(json_file)
#
# # some preparation of the data
# spotify = {}
#
# for i, item in enumerate(json_data):
#     spotify[f"song_{i}"] = item
# ```

# %%
import json
with open("/Users/dgarhdez/Desktop/IE/Python/python1-oct2021/files/spotify.json") as json_file:
    json_data = json.load(json_file)
    
# some preparation of the data
spotify = {}

for i, item in enumerate(json_data):
    spotify[f"song_{i}"] = item

# %% [markdown]
# 1. Using set comprehensions, build a container with all the artist I've listened to

# %%
unique_artists = set(info["artistName"] for _, info in spotify.items())

unique_artists
# Out:
# {'!!!',
#  '7 Notas 7 Colores',
#  '995',
#  'AC/DC',
#  'AURORA',
#  'Adele',
#  'Afrika 70',
#  'Agar Agar',
#  'Alabama Shakes',
#  'Alessandro Alessandroni',
#  'Alex Ferreira',
#  'Alice Ivy',
#  'Allman Brothers Band',
#  'Alonestar',
#  'Altin Gün',
#  'Alvvays',
#  'Ampersounds',
#  'Amy Winehouse',
#  'Anderson .Paak',
#  'Andrew Gold',
#  'Andrés Calamaro',
#  'Animal Collective',
#  'Anthony Ramos',
#  'Apani B-Fly Emcee',
#  'Arcade Fire',
#  'Arctic Monkeys',
#  'Ariel Pink',
#  'Avril Lavigne',
#  'Axel Le Baron',
#  'Axwell',
#  'Azealia Banks',
#  'BAYNK',
#  'BRONSON',
#  'Bad Bunny',
#  'Bag Raiders',
#  'Bahamas',
#  'Baird',
#  'Baltimora',
#  'Bananarama',
#  'Bandalos Chinos',
#  'Beach House',
#  'Beastie Boys',
#  'Beck',
#  'Beirut',
#  'Bejo',
#  'Belle & Sebastian',
#  'Ben Stevenson',
#  'Beny Jr',
#  'Betacam',
#  'Betty Who',
#  'Beyoncé',
#  'Big Thief',
#  'Bill Withers',
#  'Black Box',
#  'Blackberry Smoke',
#  'Bleu Toucan',
#  'Bloc Party',
#  'Blondie',
#  'Blur',
#  'Bob Dylan',
#  'Bob Marley & The Wailers',
#  'Bobby Day',
#  'Bobby Tank',
#  'Bombay Bicycle Club',
#  'Bombino',
#  'Boogarins',
#  'Brad Mehldau',
#  'Braille Face',
#  'Brenton Wood',
#  'Broken Bells',
#  'Bruno Mars',
#  'Buffalo Springfield',
#  'Bunbury',
#  'Buscabulla',
#  'C. Tangana',
#  'CHVRCHES',
#  'CLUBZ',
#  'CNCO',
#  'CRZ',
#  'CSS',
#  'Calexico',
#  'Califato ¾',
#  'Calle 13',
#  'Camel Power Club',
#  'Camille',
#  'Capital Cities',
#  'Caribou',
#  'Carlos Sadness',
#  'Carly Rae Jepsen',
#  'Carolina Durante',
#  'Cate Le Bon',
#  'Cecilio G.',
#  'Celtas Cortos',
#  'Chaka Khan',
#  'Chayanne',
#  'Chaz Bundick Meets The Mattson 2',
#  'Chilly Gonzales',
#  'Chris Isaak',
#  'Christopher Jackson',
#  'Chromeo',
#  'Cid Rim',
#  'Cihan Mürtezaoğlu',
#  'Cise Star',
#  'Claire Laffut',
#  'Clairo',
#  'Coldplay',
#  'Connan Mockasin',
#  'Cookin Soul',
#  "Cosmo's Midnight",
#  'Costa',
#  'Counting Crows',
#  'Courtney Barnett',
#  'Crooked Colours',
#  'Crystal Castles',
#  'Crystal Fighters',
#  'Cults',
#  'Curtis Mayfield',
#  'Cut Copy',
#  'DOPE LEMON',
#  'Daft Punk',
#  'Dan Kye',
#  'Danny Brown',
#  'Darren Korb',
#  'Daryl Hall & John Oates',
#  'Daveed Diggs',
#  'David Bowie',
#  'Dawn Richard',
#  'Deerhoof',
#  'Deerhunter',
#  'Delicate Steve',
#  'Delorean',
#  'Depeche Mode',
#  'Derby Motoreta’s Burrito Kachimba',
#  'Desta French',
#  'Devendra Banhart',
#  'Devon Williams',
#  'Diamante Eléctrico',
#  'Didgeridoo Aboriginal Dreamtime',
#  'Django Reinhardt',
#  'Don Patricio',
#  'Dorian',
#  'Dragonette',
#  'Drugdealer',
#  'Dungen',
#  'EPMD',
#  'Edie Brickell & New Bohemians',
#  'Edvard Grieg',
#  'Edward Sharpe & The Magnetic Zeros',
#  'El Canto Del Loco',
#  'El Columpio Asesino',
#  'El Guincho',
#  'El Jincho',
#  'El Michels Affair meets Liam Bailey',
#  'El Niño Gusano',
#  'El Palacio de Linares',
#  'El Petit De Cal Eril',
#  'Electric Guest',
#  'Elia y Elizabeth',
#  'Eliza Doolittle',
#  'Ellie Goulding',
#  'Elphomega',
#  'Elton John',
#  'Elvis Crespo',
#  'Eminem',
#  'Emmanuel Horvilleur',
#  'Empire of the Sun',
#  'Ennio Morricone',
#  'Enya',
#  'Erlend Øye',
#  'Estelle',
#  'Estopa',
#  'Eva Ryjlen',
#  'Evil Needle',
#  'FERNANDO ALFARO',
#  'FaltyDL',
#  'Favourite People',
#  'Feist',
#  'Fela Kuti',
#  'Fergie',
#  'Feu! Chatterton',
#  'Fito Paez',
#  'Fito y Fitipaldis',
#  'Five Deez',
#  'Fleet Foxes',
#  'Fleetwood Mac',
#  'Flight Facilities',
#  'Florence + The Machine',
#  'Flume',
#  'Folamour',
#  'Fontaines D.C.',
#  'Foo Fighters',
#  'Formal Chicken',
#  'Foster The People',
#  'Fran Perea',
#  'Franc Moody',
#  'Francisco Nixon',
#  'Frankie Goes To Hollywood',
#  'Françoise Hardy',
#  'French 79',
#  'French Montana',
#  'Fuerza Nueva',
#  'Fumaça Preta',
#  'Funky DL',
#  'Future Islands',
#  'GUM',
#  'Gary Burton',
#  'Gaye Su Akyol',
#  'Genesis',
#  'George Gershwin',
#  'George Harrison',
#  'George Michael',
#  'Ghost Funk Orchestra',
#  'Gipsy Kings',
#  'Glenn Frey',
#  'God Help The Girl',
#  'Goldfrapp',
#  'Good Old War',
#  'Gorillaz',
#  'Gossip',
#  'Griffith James',
#  'Grimes',
#  'Grouplove',
#  "Guns N' Roses",
#  'Gustav Mahler',
#  'HMLTD',
#  'Hamid Al Shaeri',
#  'Hannah Marcus',
#  'Hannah Montana',
#  'Hans Ernst Kroyer',
#  'Harvey Sutherland',
#  'Her',
#  "Her's",
#  'Hercules & Love Affair',
#  'Hiatus Kaiyote',
#  'Hinds',
#  'Hombres G',
#  'Horse Lords',
#  'Hot Chip',
#  'Hozier',
#  'Huey Lewis & The News',
#  'In-s',
#  'Ingrid Michaelson',
#  'Interpol',
#  "Israel Kamakawiwo'ole",
#  'Ital Tek',
#  'Ivana Spagna',
#  'J Balvin',
#  'JAY-Z',
#  'Jack Johnson',
#  'Jaga Jazzist',
#  'Jaialai',
#  'James Brown',
#  'Jamiroquai',
#  'Janko Nilovic',
#  'Japanese Breakfast',
#  'Jasmine Cephas-Jones',
#  'Jens Lekman',
#  'Jeremih',
#  'Jimi Hendrix',
#  'Johann Joseph Vilsmayr',
#  'John Grant',
#  'John Mayer',
#  'Johnny Nash',
#  'Jonah Yano',
#  'Jonas Brothers',
#  'Jonathan Groff',
#  'Joni Mitchell',
#  'Jordin Sparks',
#  'Joshua Redman',
#  'Journey',
#  'Juan Wauters',
#  'Julian Casablancas',
#  'Julio Iglesias',
#  'Jungle',
#  'Justice',
#  'KAROL G',
#  'KOKOROKO',
#  'Kanye West',
#  'Karen LeFrak',
#  'Kase.O',
#  'Kelis',
#  'Kelly Lee Owens',
#  'Kelpe',
#  'Kesha',
#  'Ketama',
#  'Khruangbin',
#  'Kikagaku Moyo',
#  'Kiko Veneno',
#  'King Gizzard & The Lizard Wizard',
#  'King Tubby',
#  'Kings of Convenience',
#  'Klaatu Suuns',
#  'Kllo',
#  'Kool & The Gang',
#  'Kora',
#  'Kraftwerk',
#  'Kurt Vile',
#  'Kyle Cook',
#  "L'Impératrice",
#  'L-Universe',
#  'LCD Soundsystem',
#  'LMFAO',
#  'La Casa Azul',
#  'La Costa Brava',
#  'La Estrella de David',
#  'La Femme',
#  'La Fuga',
#  'La Roux',
#  'Lady Gaga',
#  'Lake Street Dive',
#  'Lalalar',
#  'Leiva',
#  'Lenka',
#  'Leona Lewis',
#  'Leonard Rosenman',
#  'Leslie Odom Jr.',
#  'Leó Weiner',
#  'Lily Allen',
#  'Lin-Manuel Miranda',
#  'Lizzo',
#  'Lone',
#  'Lord Echo',
#  'Los Chikos del Maiz',
#  'Los Espiritus',
#  'Los Ganglios',
#  'Los Lobos',
#  'Los Planetas',
#  'Los Punsetes',
#  'Louis Futon',
#  'Lovely Luna',
#  'Lucía Pérez',
#  'Luke Combs',
#  'Lykke Li',
#  'M.I.A.',
#  'M83',
#  'MC Serch',
#  'MC Virgins',
#  'MGMT',
#  'Mac DeMarco',
#  'Madlib',
#  'Maggie Rogers',
#  'Mala Rodríguez',
#  'Maluca',
#  'Maluma',
#  'Manel',
#  'Mango',
#  'Mansionair',
#  'Marcia Griffiths',
#  "Mark Keali'i Ho'omalu",
#  'Mark Ronson',
#  'Maroon 5',
#  'Martina San Diego',
#  'Mats Bergström',
#  'Matt White',
#  'Matty',
#  'Maxine Nightingale',
#  'McEnroe',
#  'Mdou Moctar',
#  'Mecano',
#  'Melendi',
#  "Melody's Echo Chamber",
#  'Mesquite',
#  'Metronomy',
#  'Miami Horror',
#  'Miami Sound Machine',
#  'Michael Bublé',
#  'Michel Petrucciani',
#  'Mike Oldfield',
#  'Mike Posner',
#  'Mike Slott',
#  'Miley Cyrus',
#  'Mint Julep',
#  'Minyo Crusaders',
#  'Mishima',
#  'Mk.gee',
#  'Modern Talking',
#  'Monk',
#  'MonoNeon',
#  'Moon Blue',
#  'Moon Duo',
#  'Morgan Wallen',
#  'Morten Lava',
#  'Mujeres',
#  'Mulatu Astatke',
#  'Mumford & Sons',
#  'Muse',
#  'Musical Mania',
#  'Muzz',
#  'Myd',
#  'Mystic Braves',
#  'Nacho Vegas',
#  'Nat King Cole',
#  'Nathaniel Rateliff',
#  'Neon Indian',
#  'New Order',
#  'Nick Hakim',
#  'Nicolas Jaar',
#  'Nina Simone',
#  'No Doubt',
#  'No Vacation',
#  'Northeast Party House',
#  'Nujabes',
#  'OOIOO',
#  'Odezenne',
#  'Old Man Luedecke',
#  'One Direction',
#  'Original Broadway Cast of Hamilton',
#  'Orions Belte',
#  'P!nk',
#  'PJ Harvey',
#  'Pablo Und Destruktion',
#  'Paco de Lucía',
#  'Paradis',
#  'Parcels',
#  'Pase Rock',
#  'Pata Negra',
#  'Paul Jacobs',
#  'Paul Rosenberg',
#  'Paul Schoenfield',
#  'Peace',
#  'Pereza',
#  'Perras on the beach',
#  'Pet Shop Boys',
#  'Peter Bjorn and John',
#  'Phil Collins',
#  'Phillipa Soo',
#  'Phoenix',
#  'Phosphorescent',
#  'Pignoise',
#  'Piso 21',
#  'Polo & Pan',
#  'Poolside',
#  'Prince',
#  'Public Enemy',
#  'Purple Disco Machine',
#  'Quantic',
#  'Quintette du Hot Club de France',
#  'Quique González',
#  'ROSALÍA',
#  'Radiohead',
#  'Rainbow Kitten Surprise',
#  'Rapaz Ego',
#  'Rauw Alejandro',
#  'Ray LaMontagne',
#  'Redman',
#  'Renée Elise Goldsberry',
#  'Requin Chagrin',
#  'Residente',
#  'Rex Orange County',
#  'Rihanna',
#  'Rita Lee',
#  'Rixton',
#  'Robert Schumann',
#  'Robyn',
#  'Rod Stewart',
#  'Roland Tings',
#  'Roosevelt',
#  'Rose City Band',
#  'Rusos Blancos',
#  'Rusted Root',
#  'Röyksopp',
#  'SFDK',
#  'Scary Pockets',
#  'Sean Kingston',
#  'Sean Paul',
#  'Sebastian Yatra',
#  'Sen Senra',
#  'Sha Na Na',
#  'Shing02',
#  'Shuta Hasunuma',
#  'Sidonie',
#  'Sigur Rós',
#  'Simone Piraino',
#  'Simple Symmetry',
#  'Skinshape',
#  'Sleaford Mods',
#  'Sleigh Bells',
#  'Slugabed',
#  'Small Black',
#  'Soft Hair',
#  'Solange',
#  'Songhoy Blues',
#  'Songs: Ohia',
#  'Sons Of Kemet',
#  'Sotomayor',
#  'Spiral Starecase',
#  'Spookey Ruben',
#  'Spoon',
#  'Sr. Chinarro',
#  'St. Vincent',
#  'Stealers Wheel',
#  'Stephen Speaks',
#  'Sting',
#  'Stéphane Grappelli',
#  'Submerse',
#  'Substantial',
#  'Sufjan Stevens',
#  'Sugar Candy Mountain',
#  "Surfin' Bichos",
#  'Sweatson Klank',
#  'Swedish House Mafia',
#  'Sébastien Tellier',
#  'Sólo Los Solo',
#  'Sôber',
#  'T La Rock',
#  'TOBACCO',
#  'TOPS',
#  'Tachenko',
#  'Tame Impala',
#  'Taylor Swift',
#  'Tedeschi Trucks Band',
#  'Teenage Fanclub',
#  'Teleman',
#  'Templeton',
#  'Tennis',
#  'Thayne Jasperson',
#  'The Avalanches',
#  "The B-52's",
#  'The Beach Boys',
#  'The Beatles',
#  'The Black Keys',
#  'The Blaze',
#  'The Communards',
#  'The Coral',
#  'The Cure',
#  'The Divine Comedy',
#  'The Drums',
#  'The Head And The Heart',
#  'The Hives',
#  'The Holydrug Couple',
#  'The Ink Spots',
#  'The Innocence Mission',
#  'The Jungle Giants',
#  'The Killers',
#  "The Lovin' Spoonful",
#  'The Lumineers',
#  'The Maccabees',
#  'The New Raemon',
#  'The Offspring',
#  'The Orielles',
#  'The Pains Of Being Pure At Heart',
#  'The Pasadenas',
#  'The Pointer Sisters',
#  'The Postal Service',
#  'The Primitives',
#  'The Roots',
#  'The Rosenberg Trio',
#  'The School',
#  'The Shins',
#  'The Strokes',
#  'The Temptations',
#  'The Turtles',
#  'The Verve',
#  'The Wannadies',
#  'The Whitest Boy Alive',
#  'The Young Rascals',
#  'The xx',
#  'Thee Oh Sees',
#  'Thom Yorke',
#  'Three Dog Night',
#  'Thundercat',
#  'Tigre y Diamante',
#  'Tinariwen',
#  'Tkay Maidza',
#  'Tom G. Febonio',
#  'Tom Jones',
#  'Toro y Moi',
#  'Total Giovanni',
#  'ToteKing',
#  'Touch Sensitive',
#  'Tracy Chapman',
#  'Tropa Magica',
#  'Troy Gunner',
#  'Tunacola',
#  'Tune-Yards',
#  'Unknown Mortal Orchestra',
#  'Usher',
#  'Uyama Hiroto',
#  'Van Morrison',
#  'Van She',
#  'Vance Joy',
#  'Vanishing Twin',
#  'Venerus',
#  'Vicentico',
#  'Villagers',
#  'Violadores Del Verso',
#  'Vitalic',
#  'Vlossom',
#  'Voyou',
#  'WHY?',
#  'Wallows',
#  'Wayne Shorter',
#  'Weezer',
#  'Weste',
#  'Westlife',
#  'Wham!',
#  'When In Rome',
#  'Wiley',
#  'Winston Surfshirt',
#  'Womack & Womack',
#  'Yael Naim',
#  'Yeah Yeah Yeahs',
#  'Yellow Days',
#  'Yot Club',
#  'Young Tender',
#  'Youth Lagoon',
#  'Yukihiro Takahashi',
#  'Yung Bae',
#  'Yusuf / Cat Stevens',
#  'ZHU',
#  'ZOO',
#  'Zenit',
#  'boy pablo',
#  'clammbon',
#  'iogi',
#  'sir Was',
#  'the bird and the bee',
#  'Ø Suave'}

# %% [markdown]
# 2. Using dict comprehensions, build a dictionary with the song title as key, and the artist as value

# %%
song_artist_dict = {
    info["trackName"]: info["artistName"] for _, info in spotify.items()
}

song_artist_dict
# Out:
# {'Nunca Estoy': 'C. Tangana',
#  'Párteme La Cara': 'C. Tangana',
#  'Ingobernable': 'C. Tangana',
#  'Nominao': 'C. Tangana',
#  'Un Veneno - G-Mix': 'C. Tangana',
#  'Te Olvidaste': 'C. Tangana',
#  'CAMBIA!': 'C. Tangana',
#  'Cuándo Olvidaré': 'C. Tangana',
#  'Los Tontos': 'C. Tangana',
#  'Hong Kong': 'C. Tangana',
#  'Demasiadas Mujeres': 'C. Tangana',
#  'Tumbado En El Jardín Viendo Atardecer': 'Sen Senra',
#  'Muriendo De Envidia': 'C. Tangana',
#  'The Tearjerker Returns': 'Chilly Gonzales',
#  'Room 29': 'Chilly Gonzales',
#  'Marmont Overture': 'Chilly Gonzales',
#  'Tearjerker': 'Chilly Gonzales',
#  'Interlude 1 - Hotel Stationery': 'Chilly Gonzales',
#  'Clara': 'Chilly Gonzales',
#  'Bombshell': 'Chilly Gonzales',
#  'Belle Boy': 'Chilly Gonzales',
#  'Howard Hughes Under The Microscope': 'Chilly Gonzales',
#  'Salomé': 'Chilly Gonzales',
#  'Interlude 2 - 5 Hours A Day': 'Chilly Gonzales',
#  "Daddy, You're Not Watching Me": 'Chilly Gonzales',
#  'The Other Side': 'Chilly Gonzales',
#  'A Trick Of The Light': 'Chilly Gonzales',
#  'Room 29 (Reprise)': 'Chilly Gonzales',
#  'Echoes': 'Tennis',
#  'I Will See You Soon': 'The School',
#  'Quiet Houses': 'Fleet Foxes',
#  'Slip Away': 'Mumford & Sons',
#  'Cactus': 'Teleman',
#  'People Everywhere (Still Alive)': 'Khruangbin',
#  'Looking For Space': 'Hannah Marcus',
#  'Are You Bored Yet? (feat. Clairo)': 'Wallows',
#  'Unconditional Waltz': 'Calexico',
#  'Mission to Mars': 'Rainbow Kitten Surprise',
#  'Silver Dagger': 'Fleet Foxes',
#  'The Fear - Flipped': 'The Shins',
#  'The Wonder Of You': 'Villagers',
#  'Into the Mystic (Live at Alltel Pavilion at Walnut Creek, Raleigh, Nc, 8/10/2003)': 'Allman Brothers Band',
#  'I Pity The Fool - Live': 'Tedeschi Trucks Band',
#  'We Will Become Silhouettes (Matthew Dear Remix) - Remastered': 'The Postal Service',
#  'The High Road': 'Broken Bells',
#  'Please Don’t Ruin This For Me': 'Tennis',
#  'Beloved': 'Mumford & Sons',
#  'To the Rescue - Live': 'The Divine Comedy',
#  'Wallowa Lake Monster': 'Sufjan Stevens',
#  'When It Lands': 'Rainbow Kitten Surprise',
#  'So Long to the Headstrong': 'Fleet Foxes',
#  'Runner': 'Tennis',
#  'This Place Is a Prison - Remastered': 'The Postal Service',
#  'Dream on Mount Tam - Bonus Track': 'Calexico',
#  'Mistakes': 'Lake Street Dive',
#  'Vuelvo a Ser Yo': 'La Costa Brava',
#  'Abrazo en un Terremoto - Remasterizado': "Surfin' Bichos",
#  'Mereces Toda Mi Atención': 'Francisco Nixon',
#  'Rosa': 'Lovely Luna',
#  'Vidas cruzadas (feat. Ivan Ferreiro)': 'Quique González',
#  'Me impuse la Fuerza': 'Los Ganglios',
#  'Remar': 'Templeton',
#  'Rápido': 'Tachenko',
#  'El Bosque': 'Sidonie',
#  'Santa Fe': 'Eva Ryjlen',
#  'Cuchillo y Pentagrama': 'Tigre y Diamante',
#  'Por Mi Tripa': 'Pereza',
#  'Amor Sin Fin': 'La Estrella de David',
#  'El Año': 'Carolina Durante',
#  'Casado Con Otra': 'La Costa Brava',
#  'El Último Día Que Me Verás - Remasterizado': "Surfin' Bichos",
#  'Pimentón Húngaro': 'Rusos Blancos',
#  'Toro': 'El Columpio Asesino',
#  'Mi Anestesia': 'FERNANDO ALFARO',
#  'Canoe': 'Betacam',
#  'El Fabricante de Alas de Mariposa': 'El Niño Gusano',
#  'La Prueba del Polígrafo': 'La Costa Brava',
#  'Gente Abollada (Versión EP) - Remasterizado': "Surfin' Bichos",
#  '¿Amas Lo Desconocido? - Remasterizado': "Surfin' Bichos",
#  'Aráñame Con Cariño - Remasterizado': "Surfin' Bichos",
#  'Gente Abollada - Remasterizado': "Surfin' Bichos",
#  'Un Perro Feliz - Remasterizado': "Surfin' Bichos",
#  'La Luz en Tus Entrañas - Remasterizado': "Surfin' Bichos",
#  'Crisis - Remasterizado': "Surfin' Bichos",
#  'Vive el Peligro - Remasterizado': "Surfin' Bichos",
#  'El Rey del Pegamento - Remasterizado': "Surfin' Bichos",
#  'Malaventuranzas - Remasterizado': "Surfin' Bichos",
#  'Nada Puede Calmar Mi Sed - Remasterizado': "Surfin' Bichos",
#  'Sin Dejar de Sonreir - Remasterizado': "Surfin' Bichos",
#  'Hoppípolla': 'Sigur Rós',
#  'Varðeldur': 'Sigur Rós',
#  'Untitled #4 - Njósnavélin': 'Sigur Rós',
#  'Untitled #3 - Samskeyti': 'Sigur Rós',
#  'Svefn-g-englar': 'Sigur Rós',
#  'Dauðalogn': 'Sigur Rós',
#  'Varúð': 'Sigur Rós',
#  'Sæglópur': 'Sigur Rós',
#  'I Look To You (feat. Kimbra)': 'Miami Horror',
#  'Take Me Over': 'Cut Copy',
#  'Superego': 'Harvey Sutherland',
#  'When We Break': 'Total Giovanni',
#  'Foreign Language': 'Flight Facilities',
#  'Raro': 'Dan Kye',
#  'Standing In The Middle Of The Field': 'Cut Copy',
#  'Real Slow (feat. Sarah Chernoff)': 'Miami Horror',
#  'Just Do You': 'Lord Echo',
#  'The Difference': 'Flume',
#  'Your Light': 'Total Giovanni',
#  'Be About You': 'Winston Surfshirt',
#  'Holidays (feat. Alan Palomo)': 'Miami Horror',
#  'Sunshine': 'Flight Facilities',
#  'My Life': 'ZHU',
#  'Yesteryear': "Cosmo's Midnight",
#  'Hearts On Fire': 'Cut Copy',
#  'How Long': 'Bag Raiders',
#  'Make A Move': 'Winston Surfshirt',
#  'Pizza Guy': 'Touch Sensitive',
#  'Arty Boy': 'Flight Facilities',
#  'Need You Now': 'Cut Copy',
#  'Hold On': 'Crooked Colours',
#  'Walls to Build - Mall Grab Remix': 'Kllo',
#  'Get To Know (feat. Winston Surfshirt)': "Cosmo's Midnight",
#  'Idea Of Happiness - Original': 'Van She',
#  'Hold Me Down': 'Mansionair',
#  'Catch Your Breath': 'Vlossom',
#  'Love Language': 'Crooked Colours',
#  'HEART ATTACK (feat. lau.ra)': 'BRONSON',
#  'Be Friends': 'Alice Ivy',
#  'The Haunted': 'Northeast Party House',
#  'Faraway': 'Braille Face',
#  'Sunlight': 'Bag Raiders',
#  'DOWN': 'BAYNK',
#  'Pala': 'Roland Tings',
#  'Tú Me Dejaste De Querer': 'C. Tangana',
#  'Comerte Entera': 'C. Tangana',
#  "Le temps de l'amour - Fox Medium": 'Françoise Hardy',
#  'Home to You': 'Cate Le Bon',
#  'Computer Love - 2009 Remaster': 'Kraftwerk',
#  'Hercules Theme': 'Hercules & Love Affair',
#  'When Your Heart Says Yes - Mac DeMarco Remix': 'Spookey Ruben',
#  'Road Of The Lonely Ones': 'Madlib',
#  'Shark Smile': 'Big Thief',
#  'I Feel Alive': 'TOPS',
#  'Quiet Ferocity': 'The Jungle Giants',
#  'Space Samba (Disco Volador Theme)': 'The Orielles',
#  'Bad Feeling': 'Muzz',
#  'Little Pad - Remastered 2001': 'The Beach Boys',
#  'Troubleman': 'Electric Guest',
#  'Ayonha': 'Hamid Al Shaeri',
#  '1998 (Delicious)': 'Peace',
#  'If He': 'Mk.gee',
#  'hold yourself.': 'Tune-Yards',
#  'Inside And Out': 'Feist',
#  'Home Soon': 'DOPE LEMON',
#  'Crisantemo': 'Weste',
#  'In the Midst': 'sir Was',
#  'Ponta de Areia': 'Wayne Shorter',
#  'Powa': 'Tune-Yards',
#  'Bizness': 'Tune-Yards',
#  'Gangsta': 'Tune-Yards',
#  'Water Fountain': 'Tune-Yards',
#  'nowhere, man': 'Tune-Yards',
#  'Look at Your Hands': 'Tune-Yards',
#  'Heart Attack': 'Tune-Yards',
#  'Followed Me Back': 'Devon Williams',
#  'A Tear in the Fabric': 'Devon Williams',
#  'In Babylon': 'Devon Williams',
#  'Out of Time': 'Devon Williams',
#  'Domesticated': 'Devon Williams',
#  'Deadly Turn': 'Devon Williams',
#  'For My Memory to Collect': 'Devon Williams',
#  'Snake in the Grass': 'Devon Williams',
#  'Borderline': 'Tame Impala',
#  'Slow Motion': 'Devon Williams',
#  'Circus World': 'Devon Williams',
#  'Peace Now?': 'Devon Williams',
#  'Move on Up': 'Curtis Mayfield',
#  'Move on Up - Extended Version': 'Curtis Mayfield',
#  'Pusherman': 'Curtis Mayfield',
#  'Superfly': 'Curtis Mayfield',
#  "Here but I'm Gone": 'Curtis Mayfield',
#  "Freddie's Dead (Theme from 'Superfly')": 'Curtis Mayfield',
#  'The Makings of You': 'Curtis Mayfield',
#  "(Don't Worry) If There Is a Hell Below, We're All Going to Go": 'Curtis Mayfield',
#  'So in Love': 'Curtis Mayfield',
#  'We Got to Have Peace': 'Curtis Mayfield',
#  'Move On Up': 'Curtis Mayfield',
#  'Power to the People - Demo Version': 'Curtis Mayfield',
#  'People Get Ready - Live at Bitter End, NYC': 'Curtis Mayfield',
#  'New World Order': 'Curtis Mayfield',
#  'We the People Who Are Darker Than Blue': 'Curtis Mayfield',
#  'I Plan to Stay a Believer - Live at Bitter End, NYC': 'Curtis Mayfield',
#  "We're a Winner - Live at Bitter End, NYC": 'Curtis Mayfield',
#  'Beautiful Brother of Mine': 'Curtis Mayfield',
#  'Future Shock': 'Curtis Mayfield',
#  'Leave The Door Open': 'Bruno Mars',
#  'Bubblin': 'Anderson .Paak',
#  '24K Magic': 'Bruno Mars',
#  "That's What I Like": 'Bruno Mars',
#  'JEWELZ': 'Anderson .Paak',
#  'Uptown Funk (feat. Bruno Mars)': 'Mark Ronson',
#  'Tints (feat. Kendrick Lamar)': 'Anderson .Paak',
#  'Just the Way You Are': 'Bruno Mars',
#  'CUT EM IN (feat. Rick Ross)': 'Anderson .Paak',
#  'Grenade': 'Bruno Mars',
#  'Come Down': 'Anderson .Paak',
#  'Locked out of Heaven': 'Bruno Mars',
#  'Make It Better (feat. Smokey Robinson)': 'Anderson .Paak',
#  'Marry You': 'Bruno Mars',
#  'Lockdown': 'Anderson .Paak',
#  'Count on Me': 'Bruno Mars',
#  'Gente Con Clase': 'Los Chikos del Maiz',
#  'Vietnam': 'John Grant',
#  'How We Met, the Long Version': 'Jens Lekman',
#  'Crîtto de lâ Nabahâ': 'Califato ¾',
#  'GMF': 'John Grant',
#  'Entra En Mi Vida': 'La Casa Azul',
#  'Universal Decay': 'Ital Tek',
#  'Truth': 'Submerse',
#  'Cabinet Battle #1': 'Christopher Jackson',
#  'Korben Dallas': 'FaltyDL',
#  'Headlights': 'Troy Gunner',
#  'Shinra': 'Ital Tek',
#  'Always You': 'Sweatson Klank',
#  'Gardening': 'Mike Slott',
#  'Momma Always Told Me (feat. Stanaj & Yung Bae)': 'Mike Posner',
#  'The Divine Chord': 'The Avalanches',
#  'The Look': 'Metronomy',
#  'Suéltame, Bogotá': 'Diamante Eléctrico',
#  'Moving Men - Metronomy Remix': 'Myd',
#  "A Hero's Death - Soulwax Remix": 'Fontaines D.C.',
#  'Cielo': 'Sotomayor',
#  'El Viento Que Nos Lleva a los Dos': 'Tunacola',
#  'Polish Girl': 'Neon Indian',
#  'Not In Love - Radio Version': 'Crystal Castles',
#  "Can't Do Without You": 'Caribou',
#  'Si No Vas a Ser Tú': 'Young Tender',
#  'Hanoï café': 'Bleu Toucan',
#  'Marte': 'Kora',
#  'Áfrika': 'CLUBZ',
#  'Lights & Music': 'Cut Copy',
#  'Boys Life': 'Small Black',
#  'Nagano': 'CLUBZ',
#  'Feels Right': 'Roosevelt',
#  'Deli': 'Delorean',
#  'Stay Close': 'Delorean',
#  'As Time Breaks Off': 'Delorean',
#  'Destitute Time': 'Delorean',
#  'Seasun': 'Delorean',
#  "I'm In Love With You": 'Poolside',
#  'Real Love': 'Delorean',
#  "Don't Think Twice, It's All Right": 'Bob Dylan',
#  'Feather (feat. Cise Starr & Akin from CYNE)': 'Nujabes',
#  "Bob Dylan's Dream": 'Bob Dylan',
#  'Need Your Love': 'Tennis',
#  "Blowin' in the Wind": 'Bob Dylan',
#  'Girl from the North Country': 'Bob Dylan',
#  'Masters of War': 'Bob Dylan',
#  "A Hard Rain's A-Gonna Fall": 'Bob Dylan',
#  'Down the Highway': 'Bob Dylan',
#  "Bob Dylan's Blues": 'Bob Dylan',
#  'Oxford Town': 'Bob Dylan',
#  "Talkin' World War III Blues": 'Bob Dylan',
#  'Corrina, Corrina': 'Bob Dylan',
#  'Honey, Just Allow Me One More Chance': 'Bob Dylan',
#  'I Shall Be Free': 'Bob Dylan',
#  'L’amant malalta': 'Manel',
#  'Picking Up for You - Outtake': 'Metronomy',
#  'No Haces de Mí Lo Que No Soy': 'The New Raemon',
#  'Symphony No. 6: I. Allegro energico, ma non troppo': 'Gustav Mahler',
#  'Virus': 'Cecilio G.',
#  'Million Dollar Baby': 'Cecilio G.',
#  'THE ANIMALS': 'Cecilio G.',
#  '20 del 20': 'Costa',
#  'Pikete Espacial': 'Cecilio G.',
#  'Trankimazin': 'Cecilio G.',
#  '27 Kilates': 'El Jincho',
#  'From Darkness With Love': 'Cecilio G.',
#  '01': 'Cecilio G.',
#  '02': 'Cecilio G.',
#  '03': 'Cecilio G.',
#  '04': 'Cecilio G.',
#  'Luv(sic.) pt3 (feat. Shing02)': 'Nujabes',
#  'El Momento': 'La Casa Azul',
#  'San Borondón': 'Sr. Chinarro',
#  'Del Montón': 'Sr. Chinarro',
#  'Una Famiglia Reale': 'Sr. Chinarro',
#  'Los Ángeles': 'Sr. Chinarro',
#  'El Destino Turístico': 'Sr. Chinarro',
#  'El Progreso': 'Sr. Chinarro',
#  'Aplauso': 'Sr. Chinarro',
#  'El Rayo Verde': 'Sr. Chinarro',
#  'Efectos Especiales': 'Sr. Chinarro',
#  'Babieca': 'Sr. Chinarro',
#  'Depresión': 'Sr. Chinarro',
#  'Vacaciones en el Mar': 'Sr. Chinarro',
#  'Esplendor en la Hierba': 'Sr. Chinarro',
#  'Las Pruebas': 'Sr. Chinarro',
#  'Tímidos': 'Sr. Chinarro',
#  'Planeta B': 'Sr. Chinarro',
#  'María de las Nieves': 'Sr. Chinarro',
#  'La Buena': 'Sr. Chinarro',
#  'Quiero Hacerlo Mejor': 'Sr. Chinarro',
#  'Merche': 'Sr. Chinarro',
#  'La Odisea': 'Sr. Chinarro',
#  'Los Amores Reñidos': 'Sr. Chinarro',
#  'Escorpio': 'Sr. Chinarro',
#  'La Decoración': 'Sr. Chinarro',
#  'Mañana, Tarde y Noche': 'Sr. Chinarro',
#  'Quiromántico': 'Sr. Chinarro',
#  'El Idilio': 'Sr. Chinarro',
#  'Gitana': 'Sr. Chinarro',
#  'Más Grande Que Barcelona': 'Sr. Chinarro',
#  'Crystal Frontier': 'Calexico',
#  'Baby Don’t Believe': 'Tennis',
#  'Amazing Eyes': 'Good Old War',
#  'Gravity': 'The Whitest Boy Alive',
#  'La prima estate': 'Erlend Øye',
#  'Our Love (U Can Get)': '!!!',
#  'Eple': 'Röyksopp',
#  '49 Percent - Angello & Ingrosso Remix': 'Röyksopp',
#  'One (Your Name)': 'Swedish House Mafia',
#  'Leave The World Behind - Radio Edit': 'Axwell',
#  'Petit Prince Du Macadam': 'Folamour',
#  'Ya Just Need 2 Believe in Yaself': 'Folamour',
#  'I Miss Having Someone To Talk To': 'Folamour',
#  'These Are Just Places To Me Now': 'Folamour',
#  'Cosmic Girl - Remastered': 'Jamiroquai',
#  'Little L': 'Jamiroquai',
#  'Canned Heat': 'Jamiroquai',
#  'Automaton': 'Jamiroquai',
#  'Scam': 'Jamiroquai',
#  'Corner of the Earth': 'Jamiroquai',
#  'Rock Dust Light Star': 'Jamiroquai',
#  'Seven Days in Sunny June': 'Jamiroquai',
#  'Love Foolosophy - Radio Edit': 'Jamiroquai',
#  'Travelling Without Moving - Remastered': 'Jamiroquai',
#  'When You Gonna Learn?': 'Jamiroquai',
#  'Too Young to Die - Remastered': 'Jamiroquai',
#  'Lifeline': 'Jamiroquai',
#  'Morning Glory': 'Jamiroquai',
#  'King for a Day': 'Jamiroquai',
#  'Cloud 9': 'Jamiroquai',
#  'Space Cowboy': 'Jamiroquai',
#  'Black Capricorn Day': 'Jamiroquai',
#  'Código 6': 'Los Ganglios',
#  'Copas de Yate': 'La Costa Brava',
#  'Viaje de Redención - Remasterizado': "Surfin' Bichos",
#  'Podría Ser Peor': 'La Casa Azul',
#  'Pierde los Dientes España': 'Pablo Und Destruktion',
#  'Me Has Dejado de Gustar': 'Templeton',
#  'Un Rayo de Luz': 'McEnroe',
#  'Pesadilla En El Parque De Atracciones': 'Los Planetas',
#  'Pájaro Bendito - Remasterizado': "Surfin' Bichos",
#  'Francia la Criada y Todo': 'La Costa Brava',
#  'Conan': 'Templeton',
#  'Grown Up': 'Danny Brown',
#  "I'll Try Anything Once - Live From Electric Lady Studios for WRXP, New York": 'Julian Casablancas',
#  'Tezeta (Nostalgia)': 'Mulatu Astatke',
#  'Uman': 'KOKOROKO',
#  'Yègellé Tezeta': 'Mulatu Astatke',
#  'Tezeta': 'Mulatu Astatke',
#  'Yèkèrmo Sèw': 'Mulatu Astatke',
#  'Mulatu': 'Mulatu Astatke',
#  'Mascaram Setaba': 'Mulatu Astatke',
#  'Munayé (My Muna)': 'Mulatu Astatke',
#  'Kulun Mankwaleshi': 'Mulatu Astatke',
#  'Airglow Fires': 'Lone',
#  'Blessing It -remix (feat. Substantial & Pase Rock from Five Deez)': 'Nujabes',
#  'Horn in the middle': 'Nujabes',
#  'Lady Brown (feat. Cise Starr from CYNE)': 'Nujabes',
#  'Kumomi': 'Nujabes',
#  'Highs 2 Lows (feat. Cise Starr from CYNE)': 'Nujabes',
#  'Beat laments the world': 'Nujabes',
#  'Letter from Yokosuka': 'Nujabes',
#  'Cha Cha': 'Mulatu Astatke',
#  'Think Different (feat. Substantial)': 'Nujabes',
#  'A day by atmosphere supreme': 'Nujabes',
#  'Next view (feat. Uyama Hiroto)': 'Nujabes',
#  'Latitude -remix (feat. Five Deez)': 'Nujabes',
#  'F.I.L.O. (feat. Shing02)': 'Nujabes',
#  'Summer Gypsy': 'Nujabes',
#  'The Final View': 'Nujabes',
#  'Peaceland': 'Nujabes',
#  'ordinary joe (feat. Terry Callier)': 'Nujabes',
#  'reflection eternal': 'Nujabes',
#  'Music is mine': 'Nujabes',
#  'Eclipse (feat. Substantial)': 'Nujabes',
#  'The Sign (feat. Pase Rock)': 'Nujabes',
#  'Thank you (feat. Apani B)': 'Nujabes',
#  "World's end Rhapsody": 'Nujabes',
#  'Curar las Heridas': 'Los Chikos del Maiz',
#  'Lost In Yesterday': 'Tame Impala',
#  'Outer Space': 'John Grant',
#  'Some Dandruff On Your Shoulder': 'Jens Lekman',
#  'Anatomía de un Asesinato': 'Los Chikos del Maiz',
#  'The Less I Know The Better': 'Tame Impala',
#  'Sigourney Weaver': 'John Grant',
#  'How I Got Over': 'The Roots',
#  'Grupo Salvaje': 'Los Chikos del Maiz',
#  'Guns and Ships': 'Leslie Odom Jr.',
#  'Posthumous Forgiveness': 'Tame Impala',
#  'Libreros': 'Los Chikos del Maiz',
#  "What'd I Miss": 'Daveed Diggs',
#  'El Novio de la Muerte': 'Fuerza Nueva',
#  'Luces de Neón': 'Los Chikos del Maiz',
#  'Ten Duel Commandments': 'Anthony Ramos',
#  'Is It True': 'Tame Impala',
#  'No Pasarán': 'Los Chikos del Maiz',
#  'Washington on Your Side': 'Leslie Odom Jr.',
#  'Wake The World - Remastered 2001': 'The Beach Boys',
#  "It's Easier": 'John Grant',
#  'Comancheria': 'Los Chikos del Maiz',
#  'La Cruz': 'Fuerza Nueva',
#  'Feels Like We Only Go Backwards': 'Tame Impala',
#  "It Doesn't Matter to Him": 'John Grant',
#  'Yorktown (The World Turned Upside Down)': 'Original Broadway Cast of Hamilton',
#  'Mi Crush': 'Rusos Blancos',
#  'Modal Soul (feat. Uyama Hiroto)': 'Nujabes',
#  'flowers': 'Nujabes',
#  'sea of cloud': 'Nujabes',
#  'Light on the land': 'Nujabes',
#  'Horizon': 'Nujabes',
#  'Moon Strut (Intro)': 'Nujabes',
#  "Don't Even Try It": 'Funky DL',
#  'Strive': 'Apani B-Fly Emcee',
#  'Home Sweet Home': 'Substantial',
#  'Still Talking to You': 'Nujabes',
#  'Luv (Sic)': 'Shing02',
#  'Steadfast': 'Nujabes',
#  'Lyrical terrorists': 'Substantial',
#  'Lose my religion -remix': 'L-Universe',
#  "It's about time -fat jon remix": 'Pase Rock',
#  'Plazma Avenue -remix': 'Five Deez',
#  'D.T.F.N.': 'Cise Star',
#  "People Don't Stray": 'Funky DL',
#  'Luv (sic) pt2': 'Shing02',
#  'Voice of Autumn': 'Nujabes',
#  'SkyIs Falling (feat. C.L. Smooth)': 'Nujabes',
#  'Waltz for Life Will Born': 'Uyama Hiroto',
#  'Hikari (feat. Substantial)': 'Nujabes',
#  'Imaginary Folklore': 'clammbon',
#  'Counting Stars': 'Nujabes',
#  'Another Reflection': 'Nujabes',
#  'Devoted To U': 'Folamour',
#  'When U Came into My Life': 'Folamour',
#  'Jazz Session for No Future People': 'Folamour',
#  'The Only Thing - Live': 'Sufjan Stevens',
#  'Dunes': 'Alabama Shakes',
#  'Sofia': 'Clairo',
#  'Origins': 'Tennis',
#  'Song For Zula (Live at St. Pancras Church)': 'Phosphorescent',
#  'Again': 'Youth Lagoon',
#  'Half a Million - Flipped': 'The Shins',
#  'Moody Orange': 'Rainbow Kitten Surprise',
#  'Catherine the Great - Live': 'The Divine Comedy',
#  'The Complete Banker - Live': 'The Divine Comedy',
#  'Peer Gynt Suite No. 1, Op. 46: I. Morning Mood': 'Edvard Grieg',
#  "Peer Gynt Suite No. 2, Op. 55: I. The Abduction - Ingrid's Lament": 'Edvard Grieg',
#  'Peer Gynt Suite No. 1, Op. 46: II. The Death of Aase': 'Edvard Grieg',
#  "Peer Gynt Suite No. 1, Op. 46: III. Anitra's Dance": 'Edvard Grieg',
#  'Peer Gynt Suite No. 1, Op. 46: IV. In The Hall of The Mountain King': 'Edvard Grieg',
#  'Peer Gynt Suite No. 2, Op. 55: II. Arabian Dance': 'Edvard Grieg',
#  "Peer Gynt Suite No. 2, Op. 55: III. Peer Gynt's Homecoming": 'Edvard Grieg',
#  'Papillons, Op. 2: VII. Semplice': 'Robert Schumann',
#  'Violin Partita No. 6 in A Major: III. Saraband': 'Johann Joseph Vilsmayr',
#  'Magyar gyermek- és népdalok: No. 1, Szomorú fűzfának harminchárom ága': 'Leó Weiner',
#  'The Mother, Op. 41, FS 94, Appendix (Excerpts Arr. C. Nielsen): No. 6c, Der er et yndigt land': 'Hans Ernst Kroyer',
#  'Quiet': 'Karen LeFrak',
#  'Sogno': 'Simone Piraino',
#  'Why Me': 'Mats Bergström',
#  'Water Ballads, Op. 47: II. Sprite': 'Tom G. Febonio',
#  '4 Souvenirs (Version for Violin & Piano): No. 3, Tin Pan Alley': 'Paul Schoenfield',
#  'Minor Swing': 'Django Reinhardt',
#  'Sweet Georgia Brown': 'Django Reinhardt',
#  'Billets Doux': 'Quintette du Hot Club de France',
#  'Georgia on My Mind': 'Django Reinhardt',
#  'St. Louis Blues': 'Quintette du Hot Club de France',
#  'Blue in Green': 'Gary Burton',
#  'Oriental Shuffle': 'Django Reinhardt',
#  'Flamingo': 'Stéphane Grappelli',
#  'In a Sentimental Mood': 'Django Reinhardt',
#  'Chasing Shadows': 'Django Reinhardt',
#  'Limehouse Blues': 'Quintette du Hot Club de France',
#  'I Saw Stars (feat. Stéphane Grappelli) - Remastered 2002': 'Django Reinhardt',
#  'La mer - Beyond the Sea': 'Django Reinhardt',
#  'China Boy': 'Quintette du Hot Club de France',
#  'Swinging with Django': 'Django Reinhardt',
#  'Brick Top (feat. Stéphane Grappelli) - Remastered 2002': 'Django Reinhardt',
#  'Honeysuckle Rose': 'Django Reinhardt',
#  'I Found a New Baby': 'Quintette du Hot Club de France',
#  'Taking A Chance On Love': 'Stéphane Grappelli',
#  'Djangology (feat. Stéphane Grappelli) - Remastered 2002': 'Django Reinhardt',
#  "Here's That Rainy Day": 'Gary Burton',
#  'La chanson de rue': 'Stéphane Grappelli',
#  "(It's Only A) Paper Moon (feat. Stéphane Grappelli) - Remastered 2002": 'Django Reinhardt',
#  'Fascinating Rhythm': 'George Gershwin',
#  'I Got Rhythm': 'Quintette du Hot Club de France',
#  'Ballade - Bande originale du film "Les valseuses"': 'Stéphane Grappelli',
#  'Beyond The Sea (La Mer) (feat. Stéphane Grappelli) - Remastered 2002': 'Django Reinhardt',
#  'Cheek To Cheek': 'Stéphane Grappelli',
#  'Nuages': 'Django Reinhardt',
#  'Rain Check': 'Stéphane Grappelli',
#  "After You've Gone (feat. Stéphane Grappelli) - Remastered 2002": 'Django Reinhardt',
#  'Pent-Up House - Extended Instrumental Version (1994)': 'The Rosenberg Trio',
#  'Sweet Lorraine': 'Stéphane Grappelli',
#  'Camélia': 'Stéphane Grappelli',
#  'What Are You Doing for the Rest of Your Life': 'Stéphane Grappelli',
#  'Adelaide Eve': 'Stéphane Grappelli',
#  'Arpege': 'Gary Burton',
#  'These Foolish Things': 'Michel Petrucciani',
#  'Alexander Hamilton': 'Leslie Odom Jr.',
#  'Aaron Burr, Sir': 'Lin-Manuel Miranda',
#  'My Shot': 'Lin-Manuel Miranda',
#  'The Story of Tonight': 'Lin-Manuel Miranda',
#  'The Schuyler Sisters': 'Renée Elise Goldsberry',
#  'Farmer Refuted': 'Thayne Jasperson',
#  "You'll Be Back": 'Jonathan Groff',
#  'Right Hand Man': 'Lin-Manuel Miranda',
#  "A Winter's Ball": 'Leslie Odom Jr.',
#  'Helpless': 'Phillipa Soo',
#  'Satisfied': 'Renée Elise Goldsberry',
#  'The Story of Tonight - Reprise': 'Anthony Ramos',
#  'Wait for It': 'Leslie Odom Jr.',
#  'Stay Alive': 'Original Broadway Cast of Hamilton',
#  'Meet Me Inside': 'Lin-Manuel Miranda',
#  'That Would Be Enough': 'Phillipa Soo',
#  'History Has Its Eyes on You': 'Christopher Jackson',
#  'What Comes Next?': 'Jonathan Groff',
#  'Dear Theodosia': 'Leslie Odom Jr.',
#  'A Rising Sun': 'Mint Julep',
#  'Black Maps': 'Mint Julep',
#  'Mirage': 'Mint Julep',
#  'Lure': 'Mint Julep',
#  'Longshore Drift': 'Mint Julep',
#  'Pulse': 'Mint Julep',
#  'Lost': 'Mint Julep',
#  'In Your Sleep': 'Mint Julep',
#  'Shores': 'Mint Julep',
#  'In The Ocean': 'Mint Julep',
#  'Westerly': 'Mint Julep',
#  'No Es País para Viejos': 'Los Chikos del Maiz',
#  'Esta Ciudad Es de Mentira': 'Los Chikos del Maiz',
#  'Sin Perdón': 'Los Chikos del Maiz',
#  'El Extraño Viaje': 'Los Chikos del Maiz',
#  'Forjado a Fuego': 'Los Chikos del Maiz',
#  'Stay Alive - Reprise': 'Lin-Manuel Miranda',
#  'Take a Break': 'Phillipa Soo',
#  'Say No to This': 'Jasmine Cephas-Jones',
#  'It Might Be Time': 'Tame Impala',
#  'Glimmer': 'Tame Impala',
#  'One More Hour': 'Tame Impala',
#  'Let It Happen': 'Tame Impala',
#  'Nangs': 'Tame Impala',
#  'The Moment': 'Tame Impala',
#  "Yes I'm Changing": 'Tame Impala',
#  'Eventually': 'Tame Impala',
#  'Gossip': 'Tame Impala',
#  'Past Life': 'Tame Impala',
#  'Disciples': 'Tame Impala',
#  "'Cause I'm A Man": 'Tame Impala',
#  'Reality In Motion': 'Tame Impala',
#  'Love/Paranoia': 'Tame Impala',
#  'New Person, Same Old Mistakes': 'Tame Impala',
#  'Endors Toi - Live': 'Tame Impala',
#  "Why Won't You Make Up Your Mind? - Live": 'Tame Impala',
#  'Sestri Levante - Live': 'Tame Impala',
#  'Mind Mischief - Live': 'Tame Impala',
#  'Desire Be Desire Go - Live': 'Tame Impala',
#  'Half Full Glass Of Wine - Live': 'Tame Impala',
#  'Be Above It - Live': 'Tame Impala',
#  'Feels Like We Only Go Backwards - Live': 'Tame Impala',
#  'Apocalypse Dreams - Live': 'Tame Impala',
#  'Be Above It': 'Tame Impala',
#  'Endors Toi': 'Tame Impala',
#  'Apocalypse Dreams': 'Tame Impala',
#  'Mind Mischief': 'Tame Impala',
#  'Music To Walk Home By': 'Tame Impala',
#  "Why Won't They Talk To Me?": 'Tame Impala',
#  'Keep On Lying': 'Tame Impala',
#  'Elephant': 'Tame Impala',
#  "She Just Won't Believe Me": 'Tame Impala',
#  'Nothing That Has Happened So Far Has Been Anything We Could Control': 'Tame Impala',
#  "Sun's Coming Up": 'Tame Impala',
#  'It Is Not Meant To Be': 'Tame Impala',
#  'Desire Be Desire Go': 'Tame Impala',
#  'Alter Ego': 'Tame Impala',
#  'Lucidity': 'Tame Impala',
#  "Why Won't You Make Up Your Mind?": 'Tame Impala',
#  'Solitude Is Bliss': 'Tame Impala',
#  "Jeremy's Storm": 'Tame Impala',
#  'Expectation': 'Tame Impala',
#  'The Bold Arrow Of Time': 'Tame Impala',
#  'Runway Houses City Clouds': 'Tame Impala',
#  "I Don't Really Mind": 'Tame Impala',
#  'One More Year': 'Tame Impala',
#  'Instant Destiny': 'Tame Impala',
#  'Breathe Deeper': 'Tame Impala',
#  "Tomorrow's Dust": 'Tame Impala',
#  'On Track': 'Tame Impala',
#  'David Simon': 'Los Chikos del Maiz',
#  'Odio en las Entrañas': 'Los Chikos del Maiz',
#  "Here's to you (feat. Joan Baez)": 'Ennio Morricone',
#  'Far Rockaway Theme': 'Drugdealer',
#  'The Real World': 'Drugdealer',
#  'Suddenly': 'Drugdealer',
#  'Easy to Forget': 'Drugdealer',
#  'Were You Saying Something?': 'Drugdealer',
#  'Theme For Alessandro': 'Drugdealer',
#  "It's Only Raining Right Where You're Standing": 'Drugdealer',
#  'The End Of Comedy': 'Drugdealer',
#  'Sea of Nothing': 'Drugdealer',
#  'Congratulations': 'MGMT',
#  'Lying Has To Stop - Single Version': 'Soft Hair',
#  'Key to Love (Is Understanding) feat. Jonah Yano': 'Jonah Yano',
#  'YKWIM?': 'Yot Club',
#  "I'm The Man, That Will Find You": 'Connan Mockasin',
#  'Out Of My Head': 'Mac DeMarco',
#  'Cool Colorado': 'La Femme',
#  'Far and Safe': 'Boogarins',
#  'Windows': 'Sugar Candy Mountain',
#  'Waking Up': 'Mesquite',
#  'Ministry of Alienation': 'Unknown Mortal Orchestra',
#  'Beneath the Moon': 'Moon Blue',
#  'Orange Peel': 'Kikagaku Moyo',
#  'A Calf Born in Winter': 'Khruangbin',
#  "everything's worth it": 'iogi',
#  'Singing Didgeridoo and Sound of Nature, Forest Stream and Gentle Birds Singing, Calming Sounds of Nature for Deep Meditation Sounds of Nature White Noise for Pure Relaxation and Meditation Chakra Balance Energy Inspirational Chakra Music': 'Didgeridoo Aboriginal Dreamtime',
#  'Lilly': 'Toro y Moi',
#  'Necessary Evil': 'Unknown Mortal Orchestra',
#  'Round and Round': 'Ariel Pink',
#  'I Can Change': 'LCD Soundsystem',
#  'Runaway': 'AURORA',
#  'Avant Gardener': 'Courtney Barnett',
#  'Them Changes': 'Thundercat',
#  'Archie, Marry Me': 'Alvvays',
#  'Salad Days': 'Mac DeMarco',
#  'Desire Lines': 'Deerhunter',
#  'oh baby': 'LCD Soundsystem',
#  'Odessa': 'Caribou',
#  'Wakin On A Pretty Day': 'Kurt Vile',
#  'Road Head': 'Japanese Breakfast',
#  'Tieduprightnow': 'Parcels',
#  'Put Your Number In My Phone': 'Ariel Pink',
#  'Daffodils (feat. Kevin Parker)': 'Mark Ronson',
#  'Inside Out': 'Spoon',
#  "What's It All For?": 'Yellow Days',
#  'Positive Force': 'Delicate Steve',
#  'Seasons (Waiting on You)': 'Future Islands',
#  'Chamber Of Reflection': 'Mac DeMarco',
#  'Oblivion': 'Grimes',
#  'Lemon Glow': 'Beach House',
#  'Space Song': 'Beach House',
#  'Master of None': 'Beach House',
#  'Myth': 'Beach House',
#  'Take Care': 'Beach House',
#  'Woo': 'Beach House',
#  'Black Car': 'Beach House',
#  'Other People': 'Beach House',
#  'Dark Spring': 'Beach House',
#  'Lazuli': 'Beach House',
#  'Dive': 'Beach House',
#  'PPP': 'Beach House',
#  'Zebra': 'Beach House',
#  'Equal Mind': 'Beach House',
#  'Gila': 'Beach House',
#  'Chariot': 'Beach House',
#  'Levitation': 'Beach House',
#  'The Hours': 'Beach House',
#  'Baseball Diamond': 'Beach House',
#  'Silver Soul': 'Beach House',
#  'Majorette': 'Beach House',
#  'Indiô der çûh': 'Califato ¾',
#  'Ecô der dormío': 'Califato ¾',
#  'Canelita en rama': 'Califato ¾',
#  'Te quiero y lo çabê': 'Califato ¾',
#  'Çambra der Huebê Çanto (feat. Kurt Savoy)': 'Califato ¾',
#  'Er carrito de lô muertô (feat. Andrés de Jerez)': 'Califato ¾',
#  'Fandangô de Carmen Porter': 'Califato ¾',
#  'La bía en roça': 'Califato ¾',
#  'Er camión de lô elàô': 'Califato ¾',
#  'Pascual Márquez 33': 'Califato ¾',
#  'Guahira playera (feat. Rosana Pappalardo & María José Luna)': 'Califato ¾',
#  'Tó ba a çalîh bien mamá (feat. Queralt Lahoz)': 'Califato ¾',
#  'Camelamô naquerâh': 'Califato ¾',
#  'Contender': 'The Pains Of Being Pure At Heart',
#  "I'll Haunt You": 'Tennis',
#  'I Follow You': "Melody's Echo Chamber",
#  'Yeah (Fantasizing)': 'boy pablo',
#  'Empire Ants (feat. Little Dragon)': 'Gorillaz',
#  '505': 'Arctic Monkeys',
#  'Ei': 'ZOO',
#  'Avant': 'ZOO',
#  'Tir al Ninot': 'ZOO',
#  'Sereno': 'ZOO',
#  'Llepolies': 'ZOO',
#  "Deixa'm Que Caiga": 'ZOO',
#  'La del Futbol': 'ZOO',
#  'Diània': 'ZOO',
#  'Interludi': 'ZOO',
#  'La dels Beatles': 'ZOO',
#  'Tobogan': 'ZOO',
#  'Cançó Pòstuma': 'ZOO',
#  'Interestelar': 'Los Chikos del Maiz',
#  'San Paulo': 'Los Chikos del Maiz',
#  'Intro': 'The xx',
#  'Norteamérica Triste': 'Betacam',
#  'Why Black Man Dey Suffer': 'Fela Kuti',
#  'The Journey (feat. Zeke Manyika)': 'Folamour',
#  'Lady': 'Tune-Yards',
#  'No Agreement': 'Afrika 70',
#  'Opposite People': 'Fela Kuti',
#  'Oración del Desierto - Remasterizado': "Surfin' Bichos",
#  'Los Listos': 'Tachenko',
#  'Nuestra Última Primavera': 'Mango',
#  'Sapphire - Original Mix': 'Kyle Cook',
#  'Shoulda Known - GANZ Remix': 'Louis Futon',
#  'Tape Eater': 'TOBACCO',
#  'Titans': 'Slugabed',
#  'Draw - Dorian Concept Remix': 'Cid Rim',
#  'Constructive Interference': 'Evil Needle',
#  'Undone': 'Bobby Tank',
#  'Puds - Morgan Hislop Remix': 'Kelpe',
#  '"L"': 'Monk',
#  'Better Together': 'Luke Combs',
#  'I Can See Clearly Now - Edit': 'Johnny Nash',
#  'Sunday Morning': 'Maroon 5',
#  'Someone New': 'Hozier',
#  'Lovely Day': 'Bill Withers',
#  'Your Body Is a Wonderland': 'John Mayer',
#  'Everything': 'Michael Bublé',
#  'Big Yellow Taxi': 'Joni Mitchell',
#  'New Soul': 'Yael Naim',
#  'You And I': 'Ingrid Michaelson',
#  "Haven't Met You Yet": 'Michael Bublé',
#  'Be OK - Acoustic Version': 'Ingrid Michaelson',
#  'Just My Imagination (Running Away With Me)': 'The Temptations',
#  'Riptide': 'Vance Joy',
#  'Valerie - Live At BBC Radio 1 Live Lounge, London / 2007': 'Amy Winehouse',
#  'I Love You Always Forever': 'Betty Who',
#  'Toothpaste Kisses': 'The Maccabees',
#  "Baby I'm Yours": 'Arctic Monkeys',
#  'How Deep Is Your Love': 'the bird and the bee',
#  'From Eden': 'Hozier',
#  'L-O-V-E - Remastered': 'Nat King Cole',
#  'Rollerblades': 'Eliza Doolittle',
#  'Loving Is Easy': 'Rex Orange County',
#  'Little Bitty Pretty One': 'Bobby Day',
#  'Balay Ni Mayang': 'Martina San Diego',
#  'The Show': 'Lenka',
#  'Joy To The World': 'Three Dog Night',
#  "Good Lovin' - Single Version": 'The Young Rascals',
#  'Smile - Acoustic': 'Lily Allen',
#  'Sh-Boom (Life Could Be a Dream) - Live': 'Sha Na Na',
#  'Here Comes The Sun - Remastered 2009': 'The Beatles',
#  "It's Not Unusual": 'Tom Jones',
#  'Java Jive': 'The Ink Spots',
#  'Oogum Boogum Song': 'Brenton Wood',
#  'Rocky Raccoon': 'Scary Pockets',
#  'He Mele No Lilo': "Mark Keali'i Ho'omalu",
#  'Escape (The Pina Colada Song)': 'Jack Johnson',
#  'No Such Thing': 'John Mayer',
#  'World of Our Own': 'Westlife',
#  'More Today Than Yesterday - Single Version': 'Spiral Starecase',
#  'Lovebug': 'Jonas Brothers',
#  'Le Festin': 'Camille',
#  'In the Morning': 'The Coral',
#  'Over the Rainbow': "Israel Kamakawiwo'ole",
#  'Love (Remaster)': 'Matt White',
#  'Rich Girl': 'Daryl Hall & John Oates',
#  'Up&Up': 'Coldplay',
#  'On My Way': 'Phil Collins',
#  'Never Let Her Slip Away': 'Andrew Gold',
#  'Oh Happy Day': 'Musical Mania',
#  'Passenger Seat': 'Stephen Speaks',
#  'Army - Orchestral Abbey Road Performance / Live': 'Ellie Goulding',
#  'Underneath It All - Radio 1 Live Acoustic Version [Bonus Track]': 'No Doubt',
#  'Plateaus': 'Morten Lava',
#  'Already Yours': 'Bahamas',
#  'Stronger Than That': 'Bahamas',
#  'Up With The Jones': 'Bahamas',
#  'I Skipped A Stone': 'Old Man Luedecke',
#  'Way With Words': 'Bahamas',
#  "Don't You Want Me": 'Bahamas',
#  'Whole Wide World': 'Bahamas',
#  'Be My Witness': 'Bahamas',
#  'Half Your Love': 'Bahamas',
#  'Hockey Teeth': 'Bahamas',
#  'Til The Morning': 'Bahamas',
#  'Southern Drawl': 'Bahamas',
#  'No Expectations': 'Bahamas',
#  'Own Alone': 'Bahamas',
#  'My Love': 'Bahamas',
#  'So Free': 'Bahamas',
#  'Waves': 'Bahamas',
#  'Less Than Love': 'Bahamas',
#  'Auburn and Ivory': 'Beach House',
#  'Heart of Chambers': 'Beach House',
#  'Turtle Island': 'Beach House',
#  'Norway': 'Beach House',
#  'Saturn Song': 'Beach House',
#  'You Came To Me': 'Beach House',
#  'Saltwater': 'Beach House',
#  "She's So Lovely": 'Beach House',
#  'Wild': 'Beach House',
#  'Sparks': 'Beach House',
#  'All Your Yeahs': 'Beach House',
#  'Other Side of Phase': 'Nujabes',
#  'Dawn on the Side': 'Nujabes',
#  'Sky is Tumbling (feat. Cise Star)': 'Nujabes',
#  'Luv(sic) pt6 Uyama Hiroto Remix Instrumentals': 'Nujabes',
#  'Prayer': 'Nujabes',
#  'Luv (sic), Pt. 5 Jumpster Remix Instrumentals': 'Nujabes',
#  'Luv (sic) pt4 LASTorder Remix': 'Nujabes',
#  'Luv (sic) Grand Finale Instrumentals': 'Nujabes',
#  'Spiritual State (feat. Uyama Hiroto)': 'Nujabes',
#  'Yes (feat. Pase Rock)': 'Nujabes',
#  'Sémaphore': 'Requin Chagrin',
#  'Première vague': 'Requin Chagrin',
#  'Lamentation I': 'Sufjan Stevens',
#  'Lamentation II': 'Sufjan Stevens',
#  'Lamentation III': 'Sufjan Stevens',
#  'Déjà vu': 'Requin Chagrin',
#  'Nuit B': 'Requin Chagrin',
#  'Bye Bye Baby': 'Requin Chagrin',
#  'Juno': 'Requin Chagrin',
#  'Fou': 'Requin Chagrin',
#  'Volage': 'Requin Chagrin',
#  'Love': 'Requin Chagrin',
#  'Perséides': 'Requin Chagrin',
#  'Roi du silence': 'Requin Chagrin',
#  "Don't Blame Yourself": 'Chaz Bundick Meets The Mattson 2',
#  'Cosmetic Store': 'Jens Lekman',
#  'Farewell Transmission - Demo': 'Songs: Ohia',
#  'Under the Wheels': 'Calexico',
#  'Superstar': 'Tennis',
#  "Magician's Success": 'Vanishing Twin',
#  "If You Don't Know Now, You Never Will": 'Drugdealer',
#  'Cuffed': 'Nick Hakim',
#  'Mandala': 'Skinshape',
#  'Assume The Perpendicular - Live': 'The Divine Comedy',
#  'Follow Me': 'The Innocence Mission',
#  'You Make My Dreams (Come True)': 'Daryl Hall & John Oates',
#  'Back To Black': 'Amy Winehouse',
#  'Jolene': 'Ray LaMontagne',
#  'You And Me Song': 'The Wannadies',
#  'No More Runnin': 'Animal Collective',
#  'My Girls': 'Animal Collective',
#  'Dance, Baby!': 'boy pablo',
#  'Ready / Problems': 'boy pablo',
#  'wtf': 'boy pablo',
#  'be with me': 'boy pablo',
#  'ur phone': 'boy pablo',
#  'imreallytiredthisdaysucks': 'boy pablo',
#  'wachito rico': 'boy pablo',
#  'Beach House': 'boy pablo',
#  't-shirt': 'boy pablo',
#  'people': 'boy pablo',
#  'te vas // don’t go': 'boy pablo',
#  'Flowers': 'boy pablo',
#  'Sandbox': 'Darren Korb',
#  'La pena o la nada': 'Nacho Vegas',
#  'Crujidos': 'Nacho Vegas',
#  'Las Inmensas Preguntas': 'Nacho Vegas',
#  'Blanca': 'Nacho Vegas',
#  'En Mi Nueva Vida': 'Nacho Vegas',
#  'Cazador': 'Nacho Vegas',
#  'El Salitre': 'Nacho Vegas',
#  'La Fiesta': 'Nacho Vegas',
#  'Canción de Palacio #7': 'Nacho Vegas',
#  'Un Día Usted Morirá': 'Nacho Vegas',
#  'Días extraños': 'Bunbury',
#  'La Gran Broma Final': 'Nacho Vegas',
#  'Good Song': 'Blur',
#  'Qui més estima': 'Mishima',
#  'Som transparents': 'El Petit De Cal Eril',
#  'Man Of Oil': 'Animal Collective',
#  'NTE': 'Buscabulla',
#  'Nakamarra': 'Hiatus Kaiyote',
#  'Invisible': 'MonoNeon',
#  "Mikey's Song": 'HMLTD',
#  'Good Bad Times': 'Hinds',
#  'Dreams Never End - 2015 Remaster': 'New Order',
#  'The Mother Lode': 'Thom Yorke',
#  "Me Maten - Live at NPR's Tiny Desk": 'C. Tangana',
#  "Los Tontos - Live at NPR's Tiny Desk": 'C. Tangana',
#  'Al Final Abrazos': 'Mujeres',
#  'Después de tanto': 'Zenit',
#  'Quién es el?': 'Zenit',
#  'ya, ya, se': 'Zenit',
#  'Andegüineris': 'Zenit',
#  'Competi': 'Zenit',
#  'Un hombre y un destino': 'Zenit',
#  'Suelo soñar': 'Zenit',
#  'Siento': 'Zenit',
#  'Alcorcon rap': 'Zenit',
#  'Yulians wins': 'Zenit',
#  'Como suena': 'Zenit',
#  'Nos recordaran': 'Zenit',
#  'El acabose': 'Zenit',
#  'Producto Infinito': 'Zenit',
#  'Y más alláa la mierda': 'Zenit',
#  'De mi barrio hast atu barrio': 'Zenit',
#  'Ya, ya, se - Version 0.4': 'Zenit',
#  'Mentira - Version 0.4': 'Zenit',
#  'Memphis Blues': 'Kiko Veneno',
#  'Coge la Guitarra': 'Kiko Veneno',
#  'Los Managers': 'Kiko Veneno',
#  'San José de Arimatea': 'Kiko Veneno',
#  'Ratitas Divinas': 'Kiko Veneno',
#  'Superheroes de Barrio': 'Kiko Veneno',
#  'Hace Calor': 'Kiko Veneno',
#  'Cuando Me Levanto': 'Kiko Veneno',
#  'Quitate la Bata': 'Kiko Veneno',
#  'Joselito': 'Kiko Veneno',
#  'Valgame Juana': 'Kiko Veneno',
#  'En un Mercedes Blanco (with Martirio)': 'Kiko Veneno',
#  'Dime a': 'Kiko Veneno',
#  'Manuel': 'Kiko Veneno',
#  'Farmacia de Guardia': 'Kiko Veneno',
#  'Get Down On It - Single Version': 'Kool & The Gang',
#  'Everything She Wants': 'Wham!',
#  'Bamboléo': 'Gipsy Kings',
#  "Just Can't Get Enough": 'Depeche Mode',
#  'Got My Mind Set On You - Remastered 2004': 'George Harrison',
#  'Hip To Be Square': 'Huey Lewis & The News',
#  'I Feel for You': 'Chaka Khan',
#  'Kiss': 'Prince',
#  'Venus': 'Bananarama',
#  'Living in America - From "Rocky IV" Soundtrack': 'James Brown',
#  "Don't Leave Me This Way (with Sarah Jane Morris)": 'The Communards',
#  'The Power Of Love': 'Huey Lewis & The News',
#  'Dr. Beat': 'Miami Sound Machine',
#  'Neutron Dance': 'The Pointer Sisters',
#  'Brother Louie': 'Modern Talking',
#  'Baby Jane - 2008 Remaster': 'Rod Stewart',
#  'Love Shack': "The B-52's",
#  'Ride on Time': 'Black Box',
#  'Tarzan Boy': 'Baltimora',
#  'The Edge of Heaven': 'Wham!',
#  'Jump (For My Love)': 'The Pointer Sisters',
#  'Moonlight Shadow': 'Mike Oldfield',
#  'Relax': 'Frankie Goes To Hollywood',
#  'La Bamba': 'Los Lobos',
#  'Invisible Touch - Remastered 2007': 'Genesis',
#  'The Heat Is On - From "Beverly Hills Cop" Soundtrack': 'Glenn Frey',
#  'Freedom': 'Wham!',
#  'Call Me': 'Ivana Spagna',
#  'Todo Lo Que Me Gusta Es Ilegal': 'Pata Negra',
#  'Bodas de Sangre - Remasterizada': 'Pata Negra',
#  'Agustito': 'Ketama',
#  'Se Dejaba Llevar Por Ti': 'Ketama',
#  'Vente Pa Madrid': 'Ketama',
#  'Pozo del Deseo': 'Ketama',
#  'Puchero Light - Sevillanas': 'Ketama',
#  'Flor De Lis': 'Ketama',
#  'No Estamos Lokos (Kalikeno)': 'Ketama',
#  'Verdadero': 'Ketama',
#  'Acaba De Nacer': 'Ketama',
#  'Loko': 'Ketama',
#  'Vente Pá Madrid': 'Ketama',
#  'VCR': 'The xx',
#  'I Bet You Look Good On The Dancefloor': 'Arctic Monkeys',
#  'Aquellos Años Locos (Bonus Track)': 'El Canto Del Loco',
#  'Mykonos': 'Fleet Foxes',
#  'Shooting Stars': 'Bag Raiders',
#  'Atrévete-Te-Te': 'Calle 13',
#  'La Revolución Sexual': 'La Casa Azul',
#  'Postcards from Italy': 'Beirut',
#  'You Only Live Once': 'The Strokes',
#  'Stronger': 'Kanye West',
#  'Ámenme, Soy un Liberal': 'Nacho Vegas',
#  'Hablando en plata - 2003 Remastered Version': 'Melendi',
#  'Burning': 'The Whitest Boy Alive',
#  'Evil': 'Interpol',
#  'La Tormenta De Arena': 'Dorian',
#  'Rebellion (Lies)': 'Arcade Fire',
#  'Suavemente': 'Elvis Crespo',
#  'Uno más uno son 7': 'Fran Perea',
#  'Vino Tinto': 'Estopa',
#  'I Follow Rivers - The Magician Remix': 'Lykke Li',
#  'Hate To Say I Told You So': 'The Hives',
#  'Canciones': 'El Canto Del Loco',
#  'We Are The People': 'Empire of the Sun',
#  'Poison Lips': 'Vitalic',
#  'Como Camarón': 'Estopa',
#  'Such Great Heights - Remastered': 'The Postal Service',
#  'One More Time': 'Daft Punk',
#  'Sleeping Lessons': 'The Shins',
#  'Spilt Needles': 'The Shins',
#  'Phantom Limb': 'The Shins',
#  'Australia': 'The Shins',
#  'Black Wave': 'The Shins',
#  'Pam Berry': 'The Shins',
#  'A Comet Appears': 'The Shins',
#  'Sea Legs': 'The Shins',
#  'Red Rabbits': 'The Shins',
#  'Girl Sailor': 'The Shins',
#  'Turn On Me': 'The Shins',
#  '0to100': 'Cookin Soul',
#  ...}

# %% [markdown]
# 3. Build a dictionary of song:artist if I listened to that song for more than 10 minutes.
#
# Hint: the "msPlayed" key represents miliseconds. 1000 miliseconds = 1 second.

# %%
threshold = 10 * 60 * 1000

more_than_10_min = {
    info["trackName"]: info["artistName"] for _, info in spotify.items()
    if info["msPlayed"] > threshold
}

more_than_10_min
# Out:
# {'Svefn-g-englar': 'Sigur Rós',
#  '1998 (Delicious)': 'Peace',
#  'Devoted To U': 'Folamour',
#  'One More Hour': 'Tame Impala',
#  'Lady': 'Fela Kuti',
#  'No Agreement': 'Afrika 70',
#  'The Nearness of You': 'Joshua Redman'}
